# %% [markdown]
# # 🏥 Healthcare Data Analysis & SQL Portfolio Project
#
# ## 📌 Project Overview
# This project analyzes synthetic healthcare admission data to generate actionable insights related to hospital performance, patient conditions, insurance billing patterns, and length of stay trends.
#
# The goal of this project is to demonstrate real-world data cleaning, exploratory data analysis (EDA), KPI reporting, SQL querying, and data visualization skills relevant to an entry-level Data Analyst role.
#
# ---
#
# ## 📊 Dataset Summary
# - Total Records (after cleaning): 54,966
# - Columns: 15+ features
# - Includes:
#   - Patient demographics
#   - Medical conditions
#   - Admission & discharge dates
#   - Billing amounts
#   - Insurance providers
#   - Test results
#
# ---
#
# ## 🧹 Data Cleaning & Preparation
# - Removed 534 duplicate records
# - Standardized column naming
# - Converted date columns
# - Created Length_of_Stay feature
# - Performed outlier detection
# - Saved cleaned dataset
#
# ---
#
# ## 📈 Key KPIs
# - Average Billing Amount: ~$25,544
# - Average Length of Stay: 15.5 days
# - Most Common Condition: Arthritis
# - Most Common Admission Type: Elective
#
# ---
#
# ## 🗄 SQL Analysis
# A SQLite database was created from the cleaned dataset.
#
# SQL queries demonstrate:
# - SELECT
# - GROUP BY
# - ORDER BY
# - LIMIT
# - Aggregations
#
# Queries stored in:
# sql/queries.sql
#
# ---
#
# ## 🛠 Tools Used
# - Python (Pandas, Matplotlib)
# - SQLite
# - Jupyter Notebook
#
# ---
#
# ## 👩‍💻 Author
# Prathyusha Pentam
# Master’s in Data Science
# Texas A&M University–Corpus Christi
